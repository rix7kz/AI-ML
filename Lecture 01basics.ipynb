# %% [markdown]
# <a href="https://colab.research.google.com/github/rix7kz/AI-ML/blob/main/AI%26ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lecture 01 Basics
# Basic explanation about the course

# %%
print(3+4)
# Out:
# 7

# %%
print("hello world")
# Out:
# hello world

# %%
print("a","b","c")
# Out:
# a b c

# %%
print("thanks for the today's lecture")
# Out:
# thanks for the today's lecture

# %% [markdown]
# # Lecture 02 operators
