# %% [markdown]
# #lecture 03

# %%
#floored devision of the data

# %%
print(20//3)
# Out:
# 6

# %% [markdown]
# modulus operator

# %%
print(10%3)
# Out:
# 1

# %%
#power
print(10**3)
# Out:
# 1000

# %%
#take two int as input form the user and print all the operators

# %%
#asignment operator

# %% [markdown]
# comparison operator

# %%
#only true and false
4>3
# Out:
# True

# %%
5<=5
# Out:
# True

# %%
5<5
# Out:
# False

# %%
5==5
# Out:
# True

# %%
6==5
# Out:
# False

# %% [markdown]
# logical operator
# and , or , not

# %%
(4<5) and ( 6==8)
# Out:
# False

# %%
(4>7)
# Out:
# False

# %%
not(4>7)
# Out:
# True

# %% [markdown]
# membership operator

# %%
"a" in "aditya"
# Out:
# True
