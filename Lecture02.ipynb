# %% [markdown]
# <a href="https://colab.research.google.com/github/rix7kz/AI-ML/blob/main/Lecture02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("python")
print("sql")
# Out:
# python
# sql

# %% [markdown]
# #comments

# %%
#this is a comment example
print("why are you gay")
# Out:
# why are you gay

# %% [markdown]
# #variables

# %%
name = "akash"
place ="varanasi"
id=30

# %%
print(name)
# Out:
# akash

# %%
print(place)
# Out:
# varanasi

# %%
print(id)
# Out:
# 30

# %%
#variable rules
#start : with alphabates + _
#middle or end  : alphabates or _ or numeric value

# %% [markdown]
# #datatypes

# %%
# int:Integer
# float:float
# string:str
# boolean:bool

# %%
type(5)
# Out:
# int

# %%
type(5.5)
# Out:
# float

# %% [markdown]
# #taking input from the user

# %%
#input

# %%
name= input()
# Out:
# akash

# %%
print(name)
# Out:
# akash

# %%
name = ("enter your name :")

# %%
#take two input from the users and print their sum
s1 = input()
a=int(s1)
s2=input()
b=int(s2)
print(a+b)
# Out:
# 4
# 4
# 8

# %%
#mentos jindagi
s1=int(input())
s2=int(input())
print(s1+s2)
# Out:
# 4
# 4
# 8

# %%
#take year as an input and print his age
y=int(input())
a=2026
print(a-y)
# Out:
# 2006
# 20

# %%
print("thanks for the lecture")
# Out:
# thanks for the lecture
