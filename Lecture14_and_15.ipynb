# %% [markdown]
# <a href="https://colab.research.google.com/github/rix7kz/AI-ML/blob/main/Lecture14_and_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#to access the values of the dictionary
#student.values()

# %% [markdown]
# #tuple

# %%
#tuples are immutable

# %%
days = ("monday","tuesday")
days[0]="gandu"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4581/139142928.py in <cell line: 0>()
#       1 days = ("monday","tuesday")
# ----> 2 days[0]="gandu"
#
# TypeError: 'tuple' object does not support item assignment

# %%
a = ("akash","is","good","boy")

# %%
a[2]
# Out:
# 'good'

# %% [markdown]
# #traversing in typle

# %%
for ele in a:
  print(ele)
# Out:
# akash
# is
# good
# boy

# %%
n= len(a)
for i in range(n):
  print(a[i])
# Out:
# akash
# is
# good
# boy

# %%
num=(2,2,3,4)
print(sum(num))
# Out:
# 11

# %%
print(num.count(2))
# Out:
# 2

# %%
num.index(4)
# Out:
# 3

# %% [markdown]
# #packing and unpacking

# %%
student= ("akash",8,20)

# %%
#unpacking

# %%
name,cgpa,age = student

# %%
print(name)
# Out:
# akash

# %%
print(cgpa)
# Out:
# 8

# %%
print(age)
# Out:
# 20

# %%
def show():
  return 2,3

# %%
show(
)
# Out:
# (2, 3)

# %% [markdown]
# #Lecture 15 starts

# %%
#.lower() and .upper()
